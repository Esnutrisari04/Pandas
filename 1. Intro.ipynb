# %% [markdown]
# # Intro to data structures

# %% [markdown]
# We'll start with a quick, non-comprehensive overview of the fundamental data structures in pandas to get you started. The fundamental behavior about data types, indexing, axis lebeling, and alignment apply across all of the objects. To get started, import Numpy and load pandas into your namespace:

# %% [markdown]
# ## Import package

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Fundamentally, **data alignment is intrinsic**. The link between labels and data will not be broken unless done so explicity by you.
#
# We'll give a brief intro to the data structures, then consider all of the broad categories of functionality and methods in seperate sections.
